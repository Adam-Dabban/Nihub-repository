# %%
import pandas as pd

# %%
data = pd.read_csv("CO2_dataset.csv")

# %%
data
# Out:
#       Flue_Gas_Flow_kmolhr  Inlet_CO2_mol%  Absorber_Temp_C  LG_Ratio  \
# 0               213.657697       14.027395        58.269550  6.484772
# 1               181.648076        8.642299        50.603106  2.223628
# 2               186.204495        9.266920        31.120428  4.829722
# 3               201.267319        9.223487        30.709578  2.362949
# 4                81.362001       14.848614        51.014071  2.598737
# ...                    ...             ...              ...       ...
# 7995             80.198456       14.342358        51.582290  3.113558
# 7996            158.734126       14.533439        41.983136  4.862292
# 7997             95.246432       13.089801        41.959550  4.331304
# 7998            160.648685       15.631592        51.768342  5.247844
# 7999            101.397732        9.097934        39.764978  2.531001
#
#                 L  MEA_Concentration_wt%       T_reb  alpha_lean     P_abs  \
# ...

# %%
data.describe()
# Out:
#        Flue_Gas_Flow_kmolhr  Inlet_CO2_mol%  Absorber_Temp_C     LG_Ratio  \
# count           8000.000000     8000.000000      8000.000000  8000.000000
# mean             164.999911       12.000009        47.499992     4.250000
# std               49.077825        2.309537        10.104283     1.299119
# min               80.016287        8.000765        30.001724     2.000075
# 25%              122.503300        9.999927        38.751879     3.125061
# 50%              165.003655       11.999882        47.498944     4.249910
# 75%              207.497302       13.999448        56.250100     5.374994
# max              249.996437       15.999057        64.996832     6.499906
#
#                  L  MEA_Concentration_wt%        T_reb   alpha_lean  \
# count  8000.000000            8000.000000  8000.000000  8000.000000
# mean    805.500476              30.000000   117.499993     0.225000
# std     372.356749               5.773863     7.217319     0.043304
# ...

# %%
data.isna().sum()
# Out:
# Flue_Gas_Flow_kmolhr        0
# Inlet_CO2_mol%              0
# Absorber_Temp_C             0
# LG_Ratio                    0
# L                           0
# MEA_Concentration_wt%       0
# T_reb                       0
# alpha_lean                  0
# P_abs                       0
# CO2_Capture_Efficiency_%    0
# Reboiler_Duty_MJ_kgCO2      0
# dtype: int64

# %%
data.dropna()
# Out:
#       Flue_Gas_Flow_kmolhr  Inlet_CO2_mol%  Absorber_Temp_C  LG_Ratio  \
# 0               213.657697       14.027395        58.269550  6.484772
# 1               181.648076        8.642299        50.603106  2.223628
# 2               186.204495        9.266920        31.120428  4.829722
# 3               201.267319        9.223487        30.709578  2.362949
# 4                81.362001       14.848614        51.014071  2.598737
# ...                    ...             ...              ...       ...
# 7995             80.198456       14.342358        51.582290  3.113558
# 7996            158.734126       14.533439        41.983136  4.862292
# 7997             95.246432       13.089801        41.959550  4.331304
# 7998            160.648685       15.631592        51.768342  5.247844
# 7999            101.397732        9.097934        39.764978  2.531001
#
#                 L  MEA_Concentration_wt%       T_reb  alpha_lean     P_abs  \
# ...

# %%
import pandas as pd
train = pd.read_csv("train.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df = train.copy()

# %%
dfs = train.dropna()

# %%
dfs.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
dfs.shape
# Out:
# (183, 12)

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    28.216730
# male      30.505824
# Name: Age, dtype: float64

# %%
kids = df[df["Age"]<=10]

# %%
kids
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy
dist = numpy.random.randn(1000)

# %%
dist
# Out:
# array([ 4.74959940e-01,  3.76425825e-01,  2.83995693e-01, -1.46696577e+00,
#        -1.11156273e+00,  7.35934732e-02,  4.41670639e-01,  6.64658157e-01,
#        -9.30652459e-01,  4.65957246e-01, -7.31655889e-01,  7.48087928e-01,
#         1.24100839e+00,  1.68076841e-01, -1.85909032e-01, -6.90378488e-01,
#         4.66669984e-01, -9.49173608e-01,  3.30898628e-01, -4.01656360e-01,
#        -1.15719511e+00, -3.40913693e-01,  7.85368789e-01,  1.90833735e+00,
#         1.02131588e-01,  1.29359497e+00,  1.56884538e-01,  3.35516176e-01,
#        -1.11771333e+00, -2.28174132e-02, -9.70625738e-01,  2.22252655e-01,
#         3.14398694e+00,  7.20876245e-01,  1.94090983e+00, -4.21724830e-01,
#        -4.32337286e-01,  5.43833763e-01,  6.65087512e-01,  7.22125937e-01,
#         6.89513167e-01, -2.29431628e-02, -3.60746612e-01, -9.60996831e-02,
#         6.97373965e-01,  9.05520746e-01, -2.59289394e+00, -1.08717137e+00,
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(dist, bins=30, edgecolor = "black");
plt.title("Histogram with 30 Equal-Width bins");
plt.xlabel("Ranges");
plt.ylabel("Frequency");

# %%
! py -m pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(data = dfs, x = df["Age"], y = df["Fare"], color = "black");
plt.title("Age and Fare Dataframe",  fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Age and Fare Dataframe')

# %%
sns.boxplot(data = df);

# %%
cor = df.corr(numeric_only = True )

# %%
cor
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(cor, annot = True);
